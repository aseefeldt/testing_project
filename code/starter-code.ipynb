# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def my_mean (data_set):
    return sum(data_set)/len(data_set)
    
my_mean ([33, 4, 5, 6, 7, 23232, 8])
# Out:
# 3327.8571428571427

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def my_stand_dev (data_set):
    mean = my_mean (data_set)
    mean_squ = [(i-mean)**2 for i in data_set]
    data_set_lenght = len(data_set)
    sum_data_set = sum (mean_squ)
    return (sum_data_set/data_set_lenght)**.5


my_stand_dev ([10, 12, 23, 23, 16, 23, 21, 16])
# Out:
# 4.898979485566356

# %%
dataset = [10, 12, 23, 23, 16, 23, 21, 16]

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def percent_converter (percent_list):
    split_string = [i.replace("%", '') for i in percent_list]
    convert_per =  [int(i)/100 for i in split_string]
   
            
            
    return convert_per



percent_converter (['50%', '12%'])
# Out:
# [0.5, 0.12]

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

# %%
#reading in data, i did not end up using most of these 
#sat_17 = pd.read_csv("../data/sat_2017.csv")
sat_18 = pd.read_csv("../data/sat_2018.csv")
sat_19 = pd.read_csv("../data/sat_2019.csv")
#act_17 = pd.read_csv("../data/act_2017.csv")
#act_18 = pd.read_csv("../data/act_2019.csv")
#act_19 = pd.read_csv("../data/act_2019.csv")
sat_ca = pd.read_csv("../data/sat_2019_ca.csv")
#sat_act = pd.read_csv("../data/sat_act_by_college.csv")
#sat_19_major = pd.read_csv("../data/sat_2019_by_intended_college_major.csv")

# %%
#exploring data 
#sat_17.head()

# %%
#exploring data 
sat_18.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
#exploring data 
sat_19.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
#exploring data 
#act_17.head()

# %%
#exploring data 
#act_18.head()

# %%
#exploring data 
#act_19.head()

# %%
#exploring data 
#sat_act.head()

# %%
#exploring data 
#sat_ca.head()

# %%
sat_18.head(2)
# Out:
#      State Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama            6%                                 595   571   1166
# 1   Alaska           43%                                 562   544   1106

# %%
#combining SAT scores for exploration 
new_columns_names_for_merge_18 = {'Participation' :'participation18',
                               'Evidence-Based Reading and Writing' : 'ebrw18',
                               'Math' : 'math18',
                               'Total' : 'total18'}
sat_18.rename(columns=new_columns_names_for_merge_18, inplace =True)
sat_18.head(2)
# Out:
#      State participation18  ebrw18  math18  total18
# 0  Alabama              6%     595     571     1166
# 1   Alaska             43%     562     544     1106

# %%
new_columns_names_for_merge_19 = {'Participation Rate' :'participation19',
                               'Evidence-Based Reading and Writing' : 'ebrw19',
                               'Math' : 'math19',
                               'Total' : 'total19'}
sat_19.rename(columns=new_columns_names_for_merge_19, inplace =True)
sat_19.head(2)
# Out:
#      State participation19  EBRW  math19  total19
# 0  Alabama              7%   583     560     1143
# 1   Alaska             41%   556     541     1097

# %%
sat_18_19 =pd.merge(sat_18, sat_19, how = 'left')
sat_18_19.head()
# Out:
#         State participation18  ebrw18  math18  total18 participation19  EBRW  \
# 0     Alabama              6%     595     571     1166              7%   583
# 1      Alaska             43%     562     544     1106             41%   556
# 2     Arizona             29%     577     572     1149             31%   569
# 3    Arkansas              5%     592     576     1169              6%   582
# 4  California             60%     540     536     1076             63%   534
#
#    math19  total19
# 0     560     1143
# 1     541     1097
# 2     565     1134
# 3     559     1141
# 4     531     1065

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
#exploring datatypes 
sat_ca.dtypes
# Out:
# CDS                      float64
# CCode                    float64
# CDCode                   float64
# SCode                    float64
# RType                     object
# SName                     object
# DName                     object
# CName                     object
# Enroll12                 float64
# NumTSTTakr12             float64
# NumERWBenchmark12         object
# PctERWBenchmark12         object
# NumMathBenchmark12        object
# PctMathBenchmark12        object
# Enroll11                 float64
# NumTSTTakr11             float64
# NumERWBenchmark11         object
# PctERWBenchmark11         object
# NumMathBenchmark11        object
# PctMathBenchmark11        object
# TotNumBothBenchmark12     object
# PctBothBenchmark12        object
# TotNumBothBenchmark11     object
# PctBothBenchmark11        object
# Year                      object
# Unnamed: 25              float64
# dtype: object

# %%
#removing unneeded columns
sat_ca.drop(columns =['Unnamed: 25', 'CDS', 'SCode', 'CCode', 'CDCode', ], inplace=True)

# %%
#removing additional columns
#removed percent as we are looking for total % not just from one of the grade levels
sat_ca.drop(columns =['PctERWBenchmark12', 'PctBothBenchmark12', 'PctMathBenchmark12', 'PctERWBenchmark11', 'PctMathBenchmark11', 'PctBothBenchmark11', 'Year' ], inplace=True)

# %%
sat_ca.dtypes
# Out:
# RType                     object
# SName                     object
# DName                     object
# CName                     object
# Enroll12                 float64
# NumTSTTakr12             float64
# NumERWBenchmark12         object
# NumMathBenchmark12        object
# Enroll11                 float64
# NumTSTTakr11             float64
# NumERWBenchmark11         object
# NumMathBenchmark11        object
# TotNumBothBenchmark12     object
# TotNumBothBenchmark11     object
# dtype: object

# %%
#looking at data to confirm it worked 
sat_ca.head()
# Out:
#   RType                    SName                DName        CName  Enroll12  \
# 0     S  Colusa Alternative Home       Colusa Unified       Colusa      18.0
# 1     S          Maxwell Sr High      Maxwell Unified       Colusa      29.0
# 2     S      Belmont Senior High  Los Angeles Unified  Los Angeles     206.0
# 3     S  Canoga Park Senior High  Los Angeles Unified  Los Angeles     227.0
# 4     S     Whitman Continuation  Los Angeles Unified  Los Angeles      18.0
#
#    NumTSTTakr12 NumERWBenchmark12 NumMathBenchmark12  Enroll11  NumTSTTakr11  \
# 0           0.0               NaN                NaN      18.0           0.0
# 1          10.0                 *                  *      26.0           6.0
# 2         102.0                31                 14     219.0         174.0
# 3         113.0                54                 18     333.0         275.0
# 4          14.0                 *                  *      17.0           5.0
#
# ...

# %%
#seeing if the column has other values besides numbers before i convert to int.  
sat_ca.NumMathBenchmark11.sort_values(ascending=True)
# Out:
# 1         *
# 595       *
# 1756      *
# 1754      *
# 604       *
#        ...
# 2540    NaN
# 2571    NaN
# 2572    NaN
# 2573    NaN
# 2579    NaN
# Name: NumMathBenchmark11, Length: 2580, dtype: object

# %%
#here for reference 
sat_ca.dtypes
# Out:
# RType                     object
# SName                     object
# DName                     object
# CName                     object
# Enroll12                 float64
# NumTSTTakr12             float64
# NumERWBenchmark12         object
# NumMathBenchmark12        object
# Enroll11                 float64
# NumTSTTakr11             float64
# NumERWBenchmark11         object
# NumMathBenchmark11        object
# TotNumBothBenchmark12     object
# TotNumBothBenchmark11     object
# dtype: object

# %%
#convert to int and check for none int values 
sat_ca['NumERWBenchmark12'] = sat_ca['NumERWBenchmark12'].map(lambda NumERWBenchmark12: np.nan if NumERWBenchmark12 == '*' else float(NumERWBenchmark12))
sat_ca['NumMathBenchmark12'] = sat_ca['NumMathBenchmark12'].map(lambda NumMathBenchmark12: np.nan if NumMathBenchmark12 == '*' else float(NumMathBenchmark12))
sat_ca['NumERWBenchmark11'] = sat_ca['NumERWBenchmark11'].map(lambda NumERWBenchmark11: np.nan if NumERWBenchmark11 == '*' else float(NumERWBenchmark11))
sat_ca['NumMathBenchmark11'] = sat_ca['NumMathBenchmark11'].map(lambda NumMathBenchmark11: np.nan if NumMathBenchmark11 == '*' else float(NumMathBenchmark11))
sat_ca['TotNumBothBenchmark12'] = sat_ca['TotNumBothBenchmark12'].map(lambda TotNumBothBenchmark12: np.nan if TotNumBothBenchmark12 == '*' else float(TotNumBothBenchmark12))
sat_ca['TotNumBothBenchmark11'] = sat_ca['TotNumBothBenchmark11'].map(lambda TotNumBothBenchmark11: np.nan if TotNumBothBenchmark11 == '*' else float(TotNumBothBenchmark11))
sat_ca.dtypes
# Out:
# RType                     object
# SName                     object
# DName                     object
# CName                     object
# Enroll12                 float64
# NumTSTTakr12             float64
# NumERWBenchmark12        float64
# NumMathBenchmark12       float64
# Enroll11                 float64
# NumTSTTakr11             float64
# NumERWBenchmark11        float64
# NumMathBenchmark11       float64
# TotNumBothBenchmark12    float64
# TotNumBothBenchmark11    float64
# dtype: object

# %%
sat_ca.isnull().sum()
# Out:
# RType                      1
# SName                    598
# DName                     59
# CName                      1
# Enroll12                   1
# NumTSTTakr12               1
# NumERWBenchmark12        858
# NumMathBenchmark12       858
# Enroll11                   1
# NumTSTTakr11               1
# NumERWBenchmark11        844
# NumMathBenchmark11       844
# TotNumBothBenchmark12    858
# TotNumBothBenchmark11    844
# dtype: int64

# %%
#removing blank row 
sat_ca.dropna (subset = 'RType', inplace=True)

sat_ca.isnull().sum()
# Out:
# RType                      0
# SName                    597
# DName                     58
# CName                      0
# Enroll12                   0
# NumTSTTakr12               0
# NumERWBenchmark12        857
# NumMathBenchmark12       857
# Enroll11                   0
# NumTSTTakr11               0
# NumERWBenchmark11        843
# NumMathBenchmark11       843
# TotNumBothBenchmark12    857
# TotNumBothBenchmark11    843
# dtype: int64

# %%
#finding the percet of those students that met the math benchmark in both 11th and 12th grade
sat_ca['perct_all_math'] = (sat_ca['NumMathBenchmark12'].dropna() + sat_ca['NumMathBenchmark11'].dropna())/(sat_ca['NumTSTTakr11'].dropna() + sat_ca['NumTSTTakr12'].dropna())

# %%
#what does that look like now? 
sat_ca.head()
# Out:
#   RType                    SName                DName        CName  Enroll12  \
# 0     S  Colusa Alternative Home       Colusa Unified       Colusa      18.0
# 1     S          Maxwell Sr High      Maxwell Unified       Colusa      29.0
# 2     S      Belmont Senior High  Los Angeles Unified  Los Angeles     206.0
# 3     S  Canoga Park Senior High  Los Angeles Unified  Los Angeles     227.0
# 4     S     Whitman Continuation  Los Angeles Unified  Los Angeles      18.0
#
#    NumTSTTakr12  NumERWBenchmark12  NumMathBenchmark12  Enroll11  \
# 0           0.0                NaN                 NaN      18.0
# 1          10.0                NaN                 NaN      26.0
# 2         102.0               31.0                14.0     219.0
# 3         113.0               54.0                18.0     333.0
# 4          14.0                NaN                 NaN      17.0
#
#    NumTSTTakr11  NumERWBenchmark11  NumMathBenchmark11  TotNumBothBenchmark12  \
# ...

# %%
# I need to remove the distric only info, but i want to keep that info so i will split the table
district = sat_ca[sat_ca['RType'] == 'D']
district
# Out:
#      RType SName                         DName       CName  Enroll12  \
# 2037     D   NaN               Fremont Unified     Alameda    2537.0
# 2038     D   NaN         Piedmont City Unified     Alameda     231.0
# 2039     D   NaN           San Leandro Unified     Alameda     754.0
# 2040     D   NaN                Fresno Unified      Fresno    4593.0
# 2041     D   NaN               Mendota Unified      Fresno     234.0
# ...    ...   ...                           ...         ...       ...
# 2571     D   NaN    Oak Grove Union Elementary      Sonoma      70.0
# 2572     D   NaN  Hart-Ransom Union Elementary  Stanislaus      18.0
# 2573     D   NaN                   Keyes Union  Stanislaus      25.0
# 2574     D   NaN             Riverbank Unified  Stanislaus     179.0
# 2575     D   NaN           Davis Joint Unified        Yolo     717.0
#
#       NumTSTTakr12  NumERWBenchmark12  NumMathBenchmark12  Enroll11  \
# 2037         845.0              767.0               695.0    2555.0
# ...

# %%
#removing districs 
sat_ca.dropna(subset = 'SName', inplace=True)
sat_ca
# Out:
#      RType                    SName                            DName  \
# 0        S  Colusa Alternative Home                   Colusa Unified
# 1        S          Maxwell Sr High                  Maxwell Unified
# 2        S      Belmont Senior High              Los Angeles Unified
# 3        S  Canoga Park Senior High              Los Angeles Unified
# 4        S     Whitman Continuation              Los Angeles Unified
# ...    ...                      ...                              ...
# 1977     S       Potter Valley High  Potter Valley Community Unified
# 1978     S         Laytonville High              Laytonville Unified
# 1979     S   Eleanor Roosevelt High             Corona-Norco Unified
# 1980     S             Hughson High                  Hughson Unified
# 2036     X      State of California              State of California
#
#                     CName  Enroll12  NumTSTTakr12  NumERWBenchmark12  \
# ...

# %%
#dropping R type 
sat_ca.drop(columns =['RType' ], inplace=True)

# %%
sat_ca.head(2)
# Out:
#                      SName            DName   CName  Enroll12  NumTSTTakr12  \
# 0  Colusa Alternative Home   Colusa Unified  Colusa      18.0           0.0
# 1          Maxwell Sr High  Maxwell Unified  Colusa      29.0          10.0
#
#    NumERWBenchmark12  NumMathBenchmark12  Enroll11  NumTSTTakr11  \
# 0                NaN                 NaN      18.0           0.0
# 1                NaN                 NaN      26.0           6.0
#
#    NumERWBenchmark11  NumMathBenchmark11  TotNumBothBenchmark12  \
# 0                NaN                 NaN                    NaN
# 1                NaN                 NaN                    NaN
#
#    TotNumBothBenchmark11  perct_all_math
# 0                    NaN             NaN
# 1                    NaN             NaN

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %%
sat_ca.head()
# Out:
#                      SName                DName        CName  Enroll12  \
# 0  Colusa Alternative Home       Colusa Unified       Colusa      18.0
# 1          Maxwell Sr High      Maxwell Unified       Colusa      29.0
# 2      Belmont Senior High  Los Angeles Unified  Los Angeles     206.0
# 3  Canoga Park Senior High  Los Angeles Unified  Los Angeles     227.0
# 4     Whitman Continuation  Los Angeles Unified  Los Angeles      18.0
#
#    NumTSTTakr12  NumERWBenchmark12  NumMathBenchmark12  Enroll11  \
# 0           0.0                NaN                 NaN      18.0
# 1          10.0                NaN                 NaN      26.0
# 2         102.0               31.0                14.0     219.0
# 3         113.0               54.0                18.0     333.0
# 4          14.0                NaN                 NaN      17.0
#
#    NumTSTTakr11  NumERWBenchmark11  NumMathBenchmark11  TotNumBothBenchmark12  \
# ...

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |SName|object|sat_ca|School Name|
# |DName|object|sat_ca|School District Name|
# |CName|object|sat_ca|City in which the school is located|
# |Enroll12|float|sat_ca|12th grade enrollment for school year 2018-2019|
# |NumTSTTakr12|float|sat_ca|Number of 12th graders that took the SAT in school year 2018-2019|
# |NumERWBenchmark12|float|sat_ca|Number of 12th graders that scored 480 or higher on the English sections of the SAT|
# |NumMathBenchmark12|float|sat_ca|Number of 12th graders that scored 530 or higher on the math section of the SAT|
# |Enroll11|float|sat_ca|11th grade enrollment for school year 2018-2019|
# |NumTSTTakr11|float|sat_ca|Number of 11th graders that took the SAT in school year 2018-2019|
# |NumERWBenchmark11|float|sat_ca|Number of 11th graders that scored 480 or higher on the English sections of the SAT|
# |NumMathBenchmark11|float|sat_ca|Number of 11th graders that scored 530 or higher on the math section of the SAT|
# |TotNumBothBenchmark12|float|sat_ca|Number of 12th graders that scored 530 or higher on the math section and 480 or higher on the english sections of the SAT|
# |TotNumBothBenchmark11|float|sat_ca|Number of 11th graders that scored 530 or higher on the math section and 480 or higher on the english sections of the SAT|
# |perct_all_math|float|sat_ca|Percent of students that scored 530 or higher in math|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#taking only the float columns, Rowin helped with this 
num_cols = [i for i in sat_ca.columns if sat_ca[i].dtype is sat_ca[i].dtype == float]

# %%
#running standard deviation with the nas dropped 
[my_stand_dev(sat_ca[i].dropna()) for i in num_cols]
# Out:
# [10992.643664815803,
#  3826.3243606464725,
#  3276.4460448922896,
#  2293.786801717795,
#  10660.35297528615,
#  4640.075274661888,
#  4022.5592698074684,
#  3028.298455228205,
#  2170.820796866011,
#  2896.784285518443,
#  0.2512445145994878]

# %%
#checking to see if answers are close 
sat_ca.std()
# Out:
# C:\Users\seefe\AppData\Local\Temp\ipykernel_3588\1018548499.py:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sat_ca.std()
# Enroll12                 10995.417834
# NumTSTTakr12              3827.289995
# NumERWBenchmark12         3277.744933
# NumMathBenchmark12        2294.696132
# Enroll11                 10663.043285
# NumTSTTakr11              4641.246272
# NumERWBenchmark11         4024.125382
# NumMathBenchmark11        3029.477470
# TotNumBothBenchmark12     2171.681380
# TotNumBothBenchmark11     2897.912097
# perct_all_math               0.251349
# dtype: float64

# %%
sat_ca.head()
# Out:
#                      SName                DName        CName  Enroll12  \
# 0  Colusa Alternative Home       Colusa Unified       Colusa      18.0
# 1          Maxwell Sr High      Maxwell Unified       Colusa      29.0
# 2      Belmont Senior High  Los Angeles Unified  Los Angeles     206.0
# 3  Canoga Park Senior High  Los Angeles Unified  Los Angeles     227.0
# 4     Whitman Continuation  Los Angeles Unified  Los Angeles      18.0
#
#    NumTSTTakr12  NumERWBenchmark12  NumMathBenchmark12  Enroll11  \
# 0           0.0                NaN                 NaN      18.0
# 1          10.0                NaN                 NaN      26.0
# 2         102.0               31.0                14.0     219.0
# 3         113.0               54.0                18.0     333.0
# 4          14.0                NaN                 NaN      17.0
#
#    NumTSTTakr11  NumERWBenchmark11  NumMathBenchmark11  TotNumBothBenchmark12  \
# ...

# %%
#what are the 10 lowest schools in math 
#masking low schools  
low_schools = sat_ca.sort_values(by=['perct_all_math'], ascending=True).head(10)

# %%
#sorting new list by values
low_schools.sort_values(by=['perct_all_math'], ascending=True).head(15)
# Out:
#                                                   SName  \
# 1641                     Fairvalley High (Continuation)
# 60                        Buena Vista Continuation High
# 940                       El Camino High (Continuation)
# 416                                    Buena Vista High
# 55                                    Tranquillity High
# 420   Augustus F. Hawkins High B Community Health Ad...
# 1078                                      Frontier High
# 454                              Alternatives in Action
# 925   Augustus F. Hawkins High C Responsible Indigen...
# 1937  Academy for Multilingual Arts and Science at M...
#
#                           DName           CName  Enroll12  NumTSTTakr12  \
# 1641      Covina-Valley Unified     Los Angeles      64.0          44.0
# 60         Chino Valley Unified  San Bernardino     118.0          79.0
# 940   Norwalk-La Mirada Unified     Los Angeles     161.0          86.0
# ...

# %%
#are there common districs with low scores 
low_schools.sort_values(by = ['DName'], ascending=True)
# Out:
#                                                   SName  \
# 454                              Alternatives in Action
# 60                        Buena Vista Continuation High
# 1641                     Fairvalley High (Continuation)
# 55                                    Tranquillity High
# 420   Augustus F. Hawkins High B Community Health Ad...
# 925   Augustus F. Hawkins High C Responsible Indigen...
# 1937  Academy for Multilingual Arts and Science at M...
# 940                       El Camino High (Continuation)
# 1078                                      Frontier High
# 416                                    Buena Vista High
#
#                           DName           CName  Enroll12  NumTSTTakr12  \
# 454             Alameda Unified         Alameda      53.0          25.0
# 60         Chino Valley Unified  San Bernardino     118.0          79.0
# 1641      Covina-Valley Unified     Los Angeles      64.0          44.0
# ...

# %%
#are there also english scores at zero? There are, but more in math than in english
sat_ca.sort_values(by=['NumERWBenchmark11'], ascending=True).head(3)
# Out:
#                                    SName                DName        CName  \
# 309      Richard A. Alonzo Community Day  Los Angeles Unified  Los Angeles
# 1727          Boyle Heights Continuation  Los Angeles Unified  Los Angeles
# 1958  Pueblo de Los Angeles Continuation  Los Angeles Unified  Los Angeles
#
#       Enroll12  NumTSTTakr12  NumERWBenchmark12  NumMathBenchmark12  Enroll11  \
# 309       72.0           2.0                NaN                 NaN      15.0
# 1727       8.0           0.0                NaN                 NaN      15.0
# 1958      44.0           1.0                NaN                 NaN       4.0
#
#       NumTSTTakr11  NumERWBenchmark11  NumMathBenchmark11  \
# 309           21.0                0.0                 0.0
# 1727          17.0                0.0                 0.0
# 1958          17.0                0.0                 0.0
#
#       TotNumBothBenchmark12  TotNumBothBenchmark11  perct_all_math
# ...

# %%
#what is the mean of percent math for the whole state of CA 
sat_ca['perct_all_math'].mean()
# Out:
# 0.4867956066943575

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#box chart of pct math score, that really tells me nothing 
sns.boxplot(sat_ca['perct_all_math']);

# %%
plt.hist(sat_ca['perct_all_math'], bins = 100);

# %%
plt.hist(low_schools['perct_all_math']);

# %%
#bar chart with the schools 
sns.barplot(y = low_schools['SName'], x = low_schools['perct_all_math'])
# Out:
# <Axes: xlabel='perct_all_math', ylabel='SName'>

# %%
#for reference 
low_schools.head(2)
# Out:
#                                SName                  DName           CName  \
# 1641  Fairvalley High (Continuation)  Covina-Valley Unified     Los Angeles
# 60     Buena Vista Continuation High   Chino Valley Unified  San Bernardino
#
#       Enroll12  NumTSTTakr12  NumERWBenchmark12  NumMathBenchmark12  Enroll11  \
# 1641      64.0          44.0                7.0                 0.0      39.0
# 60       118.0          79.0                6.0                 0.0      41.0
#
#       NumTSTTakr11  NumERWBenchmark11  NumMathBenchmark11  \
# 1641          46.0                8.0                 0.0
# 60            39.0                4.0                 0.0
#
#       TotNumBothBenchmark12  TotNumBothBenchmark11  perct_all_math
# 1641                    0.0                    0.0             0.0
# 60                      0.0                    0.0             0.0

# %%
#adding mean to the data set  https://sparkbyexamples.com/pandas/how-to-append-row-to-pandas-dataframe/
mean_row = {'SName': 'CA Mean', 'perct_all_math': (sat_ca['perct_all_math'].mean())}
low_schools_mean = low_schools.append(mean_row, ignore_index=True)
# Out:
# C:\Users\seefe\AppData\Local\Temp\ipykernel_3588\1201442791.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   low_schools_mean = low_schools.append(mean_row, ignore_index=True)

# %%
low_schools_mean.head(22)
# Out:
#                                                 SName  \
# 0                      Fairvalley High (Continuation)
# 1                       Buena Vista Continuation High
# 2                       El Camino High (Continuation)
# 3                                    Buena Vista High
# 4                                   Tranquillity High
# 5   Augustus F. Hawkins High B Community Health Ad...
# 6                                       Frontier High
# 7                              Alternatives in Action
# 8   Augustus F. Hawkins High C Responsible Indigen...
# 9   Academy for Multilingual Arts and Science at M...
# 10                                            CA Mean
#
#                         DName           CName  Enroll12  NumTSTTakr12  \
# 0       Covina-Valley Unified     Los Angeles      64.0          44.0
# 1        Chino Valley Unified  San Bernardino     118.0          79.0
# 2   Norwalk-La Mirada Unified     Los Angeles     161.0          86.0
# ...

# %%
#plotting with mean for dramatic effect 
#size 
plt.figure(figsize = (15, 12))
#barplot
sns.barplot(y = low_schools_mean['SName'], x = low_schools_mean['perct_all_math'])
#title 
plt.title('Schools with Lowest Math Scores (with CA Mean)',
         fontsize = 40)
# y title 
plt.ylabel ('School Names',
           fontsize = 20) 
#x title 
plt.xlabel ('Percent of Students Who Reached or Exceded Benchmark SAT Scores',
           fontsize=20)
#X ticks 
plt.xticks(ticks = [0, .1, .2, .3, .4, .5], labels=['0', '10%', '20%', '30%', '40%', '50%']);

# %%
#plotting with out mean for readability 
#size 
plt.figure(figsize = (15, 12))
#barplot
sns.barplot(y = low_schools['SName'], x = low_schools['perct_all_math'])
#title 
plt.title('Schools with Lowest SAT Math Scores',
         fontsize = 40)
# y title 
plt.ylabel ('School Names',
           fontsize = 20) 
#x title 
plt.xlabel ('Percent of Students Who Reached or Exceded Benchmark SAT Scores',
           fontsize=20)
#X ticks 
plt.xticks(ticks = [0, .005, .01, .015, .02, .025], labels=['0', '0.5%', '1%', '1.5%', '2%', '2.5%']);

# %%
low_schools.head(10)
# Out:
#                                                   SName  \
# 1641                     Fairvalley High (Continuation)
# 60                        Buena Vista Continuation High
# 940                       El Camino High (Continuation)
# 416                                    Buena Vista High
# 55                                    Tranquillity High
# 420   Augustus F. Hawkins High B Community Health Ad...
# 1078                                      Frontier High
# 454                              Alternatives in Action
# 925   Augustus F. Hawkins High C Responsible Indigen...
# 1937  Academy for Multilingual Arts and Science at M...
#
#                           DName           CName  Enroll12  NumTSTTakr12  \
# 1641      Covina-Valley Unified     Los Angeles      64.0          44.0
# 60         Chino Valley Unified  San Bernardino     118.0          79.0
# 940   Norwalk-La Mirada Unified     Los Angeles     161.0          86.0
# ...

# %%
# showing which schools are in Greater LA 
#https://sparkbyexamples.com/pandas/pandas-drop-rows-by-index/
low_schools_la = low_schools.drop([low_schools.index[4], low_schools.index[6], low_schools.index[7]])
low_schools_la.head(7)
# Out:
#                                                   SName  \
# 1641                     Fairvalley High (Continuation)
# 60                        Buena Vista Continuation High
# 940                       El Camino High (Continuation)
# 416                                    Buena Vista High
# 420   Augustus F. Hawkins High B Community Health Ad...
# 925   Augustus F. Hawkins High C Responsible Indigen...
# 1937  Academy for Multilingual Arts and Science at M...
#
#                           DName           CName  Enroll12  NumTSTTakr12  \
# 1641      Covina-Valley Unified     Los Angeles      64.0          44.0
# 60         Chino Valley Unified  San Bernardino     118.0          79.0
# 940   Norwalk-La Mirada Unified     Los Angeles     161.0          86.0
# 416           Paramount Unified     Los Angeles     142.0          68.0
# 420         Los Angeles Unified     Los Angeles      93.0          40.0
# 925         Los Angeles Unified     Los Angeles      78.0          28.0
# ...

# %%
#plotting with mean for readability 
#size 
plt.figure(figsize = (15, 12))
#barplot
sns.barplot(y = low_schools_la['SName'], x = low_schools['perct_all_math'])
#title 
plt.title('Schools in Greater LA',
         fontsize = 40)
# y title 
plt.ylabel ('School Names',
           fontsize = 20) 
#x title 
plt.xlabel ('Percent of Students Who Reached or Exceded Benchmark SAT Scores',
           fontsize=20)
#X ticks 
plt.xticks(ticks = [0, .005, .01, .015, .02, .025], labels=['0', '0.5%', '1%', '1.5%', '2%', '2.5%']);

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Begin collaborating with these schools to to start a TEEN TECH program on or near their campus:
# Fairvalley High School
# Buena Vista Continuation High School
# El Camino High School
# Once these programs are established, consider expanding to other schools in the LA area
# Augustus F. Hawkins High School campus

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
